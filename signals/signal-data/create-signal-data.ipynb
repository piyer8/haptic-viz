# %%
import json
import os

# %%
def load_extracted_keywords(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        return json.load(file)

def load_collated_descriptions(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        return json.load(file)

def combine_data(signal_id, extracted_keywords, collated_descriptions):
    extracted_data = extracted_keywords.get(signal_id, [{}])[0]  # Safely get the first element

    # Find corresponding collated descriptions
    description_data = next((desc for desc in collated_descriptions if desc["signal_index"] == signal_id), None)

    if not description_data:
        print(f"⚠️ No description found for signal {signal_id}")
        return None

    combined_data = {
        "signal_id": signal_id,
        "sensory": {
            "keywords": extracted_data.get("sensory_keywords", []),
            "descriptions": description_data.get("sensory_descriptions", [])
        },
        "emotional": {
            "keywords": extracted_data.get("emotional_keywords", []),
            "descriptions": description_data.get("emotional_descriptions", [])
        },
        "associative": {
            "keywords": extracted_data.get("associative_keywords", []),
            "descriptions": description_data.get("associative_descriptions", [])
        }
    }

    return combined_data

# Save each signal's data as a separate JSON file
def save_combined_signal(signal_id, combined_data, output_folder):
    os.makedirs(output_folder, exist_ok=True)  # Ensure the output folder exists
    output_path = os.path.join(output_folder, f"F{signal_id}.json")
    
    with open(output_path, "w", encoding="utf-8") as output_file:
        json.dump(combined_data, output_file, indent=4)

    print(f"Saved: {output_path}")
def main():
    extracted_keywords_file = "extracted_keywords.json"
    collated_descriptions_file = "collated_descriptions.json"
    output_folder = "./signal-descriptions"

    extracted_keywords = load_extracted_keywords(extracted_keywords_file)
    collated_descriptions = load_collated_descriptions(collated_descriptions_file)

    # Process each signal from extracted keywords
    for signal_id in extracted_keywords.keys():
        combined_data = combine_data(signal_id, extracted_keywords, collated_descriptions)
        if combined_data:
            save_combined_signal(signal_id, combined_data, output_folder)

# Run the script
if __name__ == "__main__":
    main()
# Out:
# ✅ Saved: ./signal-descriptions/F113.json
# ✅ Saved: ./signal-descriptions/F114.json
# ✅ Saved: ./signal-descriptions/F115.json
# ✅ Saved: ./signal-descriptions/F116.json
# ✅ Saved: ./signal-descriptions/F117.json
# ✅ Saved: ./signal-descriptions/F118.json
# ✅ Saved: ./signal-descriptions/F119.json
# ✅ Saved: ./signal-descriptions/F120.json
# ✅ Saved: ./signal-descriptions/F121.json
# ✅ Saved: ./signal-descriptions/F122.json
# ✅ Saved: ./signal-descriptions/F123.json
# ✅ Saved: ./signal-descriptions/F124.json
# ✅ Saved: ./signal-descriptions/F125.json
# ✅ Saved: ./signal-descriptions/F126.json
# ✅ Saved: ./signal-descriptions/F127.json
# ✅ Saved: ./signal-descriptions/F128.json
# ✅ Saved: ./signal-descriptions/F89.json
# ✅ Saved: ./signal-descriptions/F98.json
# ✅ Saved: ./signal-descriptions/F99.json
# ✅ Saved: ./signal-descriptions/F100.json
# ✅ Saved: ./signal-descriptions/F101.json
# ✅ Saved: ./signal-descriptions/F102.json
# ✅ Saved: ./signal-descriptions/F103.json
# ✅ Saved: ./signal-descriptions/F104.json
# ✅ Saved: ./signal-descriptions/F105.json
# ✅ Saved: ./signal-descriptions/F106.json
# ✅ Saved: ./signal-descriptions/F107.json
# ✅ Saved: ./signal-descriptions/F108.json
# ✅ Saved: ./signal-descriptions/F109.json
# ✅ Saved: ./signal-descriptions/F110.json
# ✅ Saved: ./signal-descriptions/F111.json
# ✅ Saved: ./signal-descriptions/F112.json
# ✅ Saved: ./signal-descriptions/F145.json
# ✅ Saved: ./signal-descriptions/F146.json
# ✅ Saved: ./signal-descriptions/F147.json
# ✅ Saved: ./signal-descriptions/F148.json
# ✅ Saved: ./signal-descriptions/F161.json
# ✅ Saved: ./signal-descriptions/F150.json
# ✅ Saved: ./signal-descriptions/F151.json
# ✅ Saved: ./signal-descriptions/F152.json
# ✅ Saved: ./signal-descriptions/F153.json
# ✅ Saved: ./signal-descriptions/F162.json
# ✅ Saved: ./signal-descriptions/F155.json
# ✅ Saved: ./signal-descriptions/F156.json
# ✅ Saved: ./signal-descriptions/F157.json
# ✅ Saved: ./signal-descriptions/F158.json
# ✅ Saved: ./signal-descriptions/F159.json
# ✅ Saved: ./signal-descriptions/F160.json
# ✅ Saved: ./signal-descriptions/F129.json
# ✅ Saved: ./signal-descriptions/F130.json
# ✅ Saved: ./signal-descriptions/F131.json
# ✅ Saved: ./signal-descriptions/F132.json
# ✅ Saved: ./signal-descriptions/F133.json
# ✅ Saved: ./signal-descriptions/F134.json
# ✅ Saved: ./signal-descriptions/F135.json
# ✅ Saved: ./signal-descriptions/F136.json
# ✅ Saved: ./signal-descriptions/F137.json
# ✅ Saved: ./signal-descriptions/F138.json
# ✅ Saved: ./signal-descriptions/F139.json
# ✅ Saved: ./signal-descriptions/F140.json
# ✅ Saved: ./signal-descriptions/F141.json
# ✅ Saved: ./signal-descriptions/F142.json
# ✅ Saved: ./signal-descriptions/F143.json
# ✅ Saved: ./signal-descriptions/F144.json
# ✅ Saved: ./signal-descriptions/F33.json
# ✅ Saved: ./signal-descriptions/F37.json
# ✅ Saved: ./signal-descriptions/F38.json
# ✅ Saved: ./signal-descriptions/F41.json
# ✅ Saved: ./signal-descriptions/F42.json
# ✅ Saved: ./signal-descriptions/F44.json
# ✅ Saved: ./signal-descriptions/F45.json
# ✅ Saved: ./signal-descriptions/F46.json
# ✅ Saved: ./signal-descriptions/F49.json
# ✅ Saved: ./signal-descriptions/F50.json
# ✅ Saved: ./signal-descriptions/F51.json
# ✅ Saved: ./signal-descriptions/F57.json
# ✅ Saved: ./signal-descriptions/F58.json
# ✅ Saved: ./signal-descriptions/F59.json
# ✅ Saved: ./signal-descriptions/F64.json
# ✅ Saved: ./signal-descriptions/F65.json
# ✅ Saved: ./signal-descriptions/F47.json
# ✅ Saved: ./signal-descriptions/F61.json
# ✅ Saved: ./signal-descriptions/F67.json
# ✅ Saved: ./signal-descriptions/F68.json
# ✅ Saved: ./signal-descriptions/F69.json
# ✅ Saved: ./signal-descriptions/F70.json
# ✅ Saved: ./signal-descriptions/F71.json
# ✅ Saved: ./signal-descriptions/F72.json
# ✅ Saved: ./signal-descriptions/F73.json
# ✅ Saved: ./signal-descriptions/F74.json
# ✅ Saved: ./signal-descriptions/F75.json
# ✅ Saved: ./signal-descriptions/F76.json
# ✅ Saved: ./signal-descriptions/F77.json
# ✅ Saved: ./signal-descriptions/F78.json
# ✅ Saved: ./signal-descriptions/F79.json
# ✅ Saved: ./signal-descriptions/F80.json
# ✅ Saved: ./signal-descriptions/F34.json
# ✅ Saved: ./signal-descriptions/F35.json
# ✅ Saved: ./signal-descriptions/F36.json
# ✅ Saved: ./signal-descriptions/F39.json
# ✅ Saved: ./signal-descriptions/F40.json
# ✅ Saved: ./signal-descriptions/F43.json
# ✅ Saved: ./signal-descriptions/F48.json
# ✅ Saved: ./signal-descriptions/F52.json
# ✅ Saved: ./signal-descriptions/F53.json
# ✅ Saved: ./signal-descriptions/F54.json
# ✅ Saved: ./signal-descriptions/F55.json
# ✅ Saved: ./signal-descriptions/F56.json
# ✅ Saved: ./signal-descriptions/F60.json
# ✅ Saved: ./signal-descriptions/F62.json
# ✅ Saved: ./signal-descriptions/F63.json
# ✅ Saved: ./signal-descriptions/F66.json
# ✅ Saved: ./signal-descriptions/F1.json
# ✅ Saved: ./signal-descriptions/F5.json
# ✅ Saved: ./signal-descriptions/F6.json
# ✅ Saved: ./signal-descriptions/F9.json
# ✅ Saved: ./signal-descriptions/F10.json
# ✅ Saved: ./signal-descriptions/F12.json
# ✅ Saved: ./signal-descriptions/F13.json
# ✅ Saved: ./signal-descriptions/F14.json
# ✅ Saved: ./signal-descriptions/F16.json
# ✅ Saved: ./signal-descriptions/F17.json
# ✅ Saved: ./signal-descriptions/F18.json
# ✅ Saved: ./signal-descriptions/F24.json
# ✅ Saved: ./signal-descriptions/F25.json
# ✅ Saved: ./signal-descriptions/F26.json
# ✅ Saved: ./signal-descriptions/F30.json
# ✅ Saved: ./signal-descriptions/F31.json
# ✅ Saved: ./signal-descriptions/F2.json
# ✅ Saved: ./signal-descriptions/F3.json
# ✅ Saved: ./signal-descriptions/F4.json
# ✅ Saved: ./signal-descriptions/F7.json
# ✅ Saved: ./signal-descriptions/F8.json
# ✅ Saved: ./signal-descriptions/F11.json
# ✅ Saved: ./signal-descriptions/F15.json
# ✅ Saved: ./signal-descriptions/F19.json
# ✅ Saved: ./signal-descriptions/F20.json
# ✅ Saved: ./signal-descriptions/F21.json
# ✅ Saved: ./signal-descriptions/F22.json
# ✅ Saved: ./signal-descriptions/F23.json
# ✅ Saved: ./signal-descriptions/F27.json
# ✅ Saved: ./signal-descriptions/F28.json
# ✅ Saved: ./signal-descriptions/F29.json
# ✅ Saved: ./signal-descriptions/F32.json
# ✅ Saved: ./signal-descriptions/F81.json
# ✅ Saved: ./signal-descriptions/F82.json
# ✅ Saved: ./signal-descriptions/F83.json
# ✅ Saved: ./signal-descriptions/F84.json
# ✅ Saved: ./signal-descriptions/F85.json
# ✅ Saved: ./signal-descriptions/F87.json
# ✅ Saved: ./signal-descriptions/F88.json
# ✅ Saved: ./signal-descriptions/F90.json
# ✅ Saved: ./signal-descriptions/F91.json
# ✅ Saved: ./signal-descriptions/F92.json
# ✅ Saved: ./signal-descriptions/F93.json
# ✅ Saved: ./signal-descriptions/F94.json
# ✅ Saved: ./signal-descriptions/F95.json
# ✅ Saved: ./signal-descriptions/F96.json
# ✅ Saved: ./signal-descriptions/F97.json
