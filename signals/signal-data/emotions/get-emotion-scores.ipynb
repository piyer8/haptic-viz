# %%
import json
import os

# %%
nrc_path = './NRC-Emotion-Intensity-Lexicon/NRC-Emotion-Intensity-Lexicon-v1.txt'
word_data = []

with open(nrc_path) as f:
    for line in f:
        parts = line.strip().split('\t')
        word = parts[0]
        emotion = parts[1]
        intensity = parts[2]
        word_data.append({"word": word, "emotion": emotion, "intensity": intensity})

# %%
keywords_path = './extracted_keywords.json'
with open(keywords_path) as f:
    keywords_data = json.load(f)

def process_signal(signal_id, signal_data):
    processed_entries = []
    keyword_scores = []
    for entry in signal_data:
        emotional_keywords = entry["emotional_keywords"][0].split(", ")
        emotional_keywords = [keyword.replace(" ", "").lower() for keyword in emotional_keywords]

        for keyword in emotional_keywords:
            matches = [d for d in word_data if d["word"] == keyword]
            keyword_scores.extend(matches)
        #keyword_scores = [d for d in word_data if d["word"] in emotional_keywords]

        processed_entries.append({
            "signal_id": signal_id,
            "emotional_keywords": keyword_scores
        })

    return processed_entries

def save_processed_signal(signal_id, processed_data, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    output_path = os.path.join(output_folder, f"F{signal_id}.json")
    
    with open(output_path, "w", encoding="utf-8") as output_file:
        json.dump(processed_data, output_file, indent=4)

    print(f"Processed and saved: {output_path}")

def main():
    output_folder = "./emotional-data/"
    for signal_id, signal_list in keywords_data.items():
        processed_data = process_signal(signal_id, signal_list)
        save_processed_signal(signal_id, processed_data, output_folder)

if __name__ == "__main__":
    main()
# Out:
# Processed and saved: ./emotional-data/F113.json
# Processed and saved: ./emotional-data/F114.json
# Processed and saved: ./emotional-data/F115.json
# Processed and saved: ./emotional-data/F116.json
# Processed and saved: ./emotional-data/F117.json
# Processed and saved: ./emotional-data/F118.json
# Processed and saved: ./emotional-data/F119.json
# Processed and saved: ./emotional-data/F120.json
# Processed and saved: ./emotional-data/F121.json
# Processed and saved: ./emotional-data/F122.json
# Processed and saved: ./emotional-data/F123.json
# Processed and saved: ./emotional-data/F124.json
# Processed and saved: ./emotional-data/F125.json
# Processed and saved: ./emotional-data/F126.json
# Processed and saved: ./emotional-data/F127.json
# Processed and saved: ./emotional-data/F128.json
# Processed and saved: ./emotional-data/F89.json
# Processed and saved: ./emotional-data/F98.json
# Processed and saved: ./emotional-data/F99.json
# Processed and saved: ./emotional-data/F100.json
# Processed and saved: ./emotional-data/F101.json
# Processed and saved: ./emotional-data/F102.json
# Processed and saved: ./emotional-data/F103.json
# Processed and saved: ./emotional-data/F104.json
# Processed and saved: ./emotional-data/F105.json
# Processed and saved: ./emotional-data/F106.json
# Processed and saved: ./emotional-data/F107.json
# Processed and saved: ./emotional-data/F108.json
# Processed and saved: ./emotional-data/F109.json
# Processed and saved: ./emotional-data/F110.json
# Processed and saved: ./emotional-data/F111.json
# Processed and saved: ./emotional-data/F112.json
# Processed and saved: ./emotional-data/F145.json
# Processed and saved: ./emotional-data/F146.json
# Processed and saved: ./emotional-data/F147.json
# Processed and saved: ./emotional-data/F148.json
# Processed and saved: ./emotional-data/F161.json
# Processed and saved: ./emotional-data/F150.json
# Processed and saved: ./emotional-data/F151.json
# Processed and saved: ./emotional-data/F152.json
# Processed and saved: ./emotional-data/F153.json
# Processed and saved: ./emotional-data/F162.json
# Processed and saved: ./emotional-data/F155.json
# Processed and saved: ./emotional-data/F156.json
# Processed and saved: ./emotional-data/F157.json
# Processed and saved: ./emotional-data/F158.json
# Processed and saved: ./emotional-data/F159.json
# Processed and saved: ./emotional-data/F160.json
# Processed and saved: ./emotional-data/F129.json
# Processed and saved: ./emotional-data/F130.json
# Processed and saved: ./emotional-data/F131.json
# Processed and saved: ./emotional-data/F132.json
# Processed and saved: ./emotional-data/F133.json
# Processed and saved: ./emotional-data/F134.json
# Processed and saved: ./emotional-data/F135.json
# Processed and saved: ./emotional-data/F136.json
# Processed and saved: ./emotional-data/F137.json
# Processed and saved: ./emotional-data/F138.json
# Processed and saved: ./emotional-data/F139.json
# Processed and saved: ./emotional-data/F140.json
# Processed and saved: ./emotional-data/F141.json
# Processed and saved: ./emotional-data/F142.json
# Processed and saved: ./emotional-data/F143.json
# Processed and saved: ./emotional-data/F144.json
# Processed and saved: ./emotional-data/F33.json
# Processed and saved: ./emotional-data/F37.json
# Processed and saved: ./emotional-data/F38.json
# Processed and saved: ./emotional-data/F41.json
# Processed and saved: ./emotional-data/F42.json
# Processed and saved: ./emotional-data/F44.json
# Processed and saved: ./emotional-data/F45.json
# Processed and saved: ./emotional-data/F46.json
# Processed and saved: ./emotional-data/F49.json
# Processed and saved: ./emotional-data/F50.json
# Processed and saved: ./emotional-data/F51.json
# Processed and saved: ./emotional-data/F57.json
# Processed and saved: ./emotional-data/F58.json
# Processed and saved: ./emotional-data/F59.json
# Processed and saved: ./emotional-data/F64.json
# Processed and saved: ./emotional-data/F65.json
# Processed and saved: ./emotional-data/F47.json
# Processed and saved: ./emotional-data/F61.json
# Processed and saved: ./emotional-data/F67.json
# Processed and saved: ./emotional-data/F68.json
# Processed and saved: ./emotional-data/F69.json
# Processed and saved: ./emotional-data/F70.json
# Processed and saved: ./emotional-data/F71.json
# Processed and saved: ./emotional-data/F72.json
# Processed and saved: ./emotional-data/F73.json
# Processed and saved: ./emotional-data/F74.json
# Processed and saved: ./emotional-data/F75.json
# Processed and saved: ./emotional-data/F76.json
# Processed and saved: ./emotional-data/F77.json
# Processed and saved: ./emotional-data/F78.json
# Processed and saved: ./emotional-data/F79.json
# Processed and saved: ./emotional-data/F80.json
# Processed and saved: ./emotional-data/F34.json
# Processed and saved: ./emotional-data/F35.json
# Processed and saved: ./emotional-data/F36.json
# Processed and saved: ./emotional-data/F39.json
# Processed and saved: ./emotional-data/F40.json
# Processed and saved: ./emotional-data/F43.json
# Processed and saved: ./emotional-data/F48.json
# Processed and saved: ./emotional-data/F52.json
# Processed and saved: ./emotional-data/F53.json
# Processed and saved: ./emotional-data/F54.json
# Processed and saved: ./emotional-data/F55.json
# Processed and saved: ./emotional-data/F56.json
# Processed and saved: ./emotional-data/F60.json
# Processed and saved: ./emotional-data/F62.json
# Processed and saved: ./emotional-data/F63.json
# Processed and saved: ./emotional-data/F66.json
# Processed and saved: ./emotional-data/F1.json
# Processed and saved: ./emotional-data/F5.json
# Processed and saved: ./emotional-data/F6.json
# Processed and saved: ./emotional-data/F9.json
# Processed and saved: ./emotional-data/F10.json
# Processed and saved: ./emotional-data/F12.json
# Processed and saved: ./emotional-data/F13.json
# Processed and saved: ./emotional-data/F14.json
# Processed and saved: ./emotional-data/F16.json
# Processed and saved: ./emotional-data/F17.json
# Processed and saved: ./emotional-data/F18.json
# Processed and saved: ./emotional-data/F24.json
# Processed and saved: ./emotional-data/F25.json
# Processed and saved: ./emotional-data/F26.json
# Processed and saved: ./emotional-data/F30.json
# Processed and saved: ./emotional-data/F31.json
# Processed and saved: ./emotional-data/F2.json
# Processed and saved: ./emotional-data/F3.json
# Processed and saved: ./emotional-data/F4.json
# Processed and saved: ./emotional-data/F7.json
# Processed and saved: ./emotional-data/F8.json
# Processed and saved: ./emotional-data/F11.json
# Processed and saved: ./emotional-data/F15.json
# Processed and saved: ./emotional-data/F19.json
# Processed and saved: ./emotional-data/F20.json
# Processed and saved: ./emotional-data/F21.json
# Processed and saved: ./emotional-data/F22.json
# Processed and saved: ./emotional-data/F23.json
# Processed and saved: ./emotional-data/F27.json
# Processed and saved: ./emotional-data/F28.json
# Processed and saved: ./emotional-data/F29.json
# Processed and saved: ./emotional-data/F32.json
# Processed and saved: ./emotional-data/F81.json
# Processed and saved: ./emotional-data/F82.json
# Processed and saved: ./emotional-data/F83.json
# Processed and saved: ./emotional-data/F84.json
# Processed and saved: ./emotional-data/F85.json
# Processed and saved: ./emotional-data/F87.json
# Processed and saved: ./emotional-data/F88.json
# Processed and saved: ./emotional-data/F90.json
# Processed and saved: ./emotional-data/F91.json
# Processed and saved: ./emotional-data/F92.json
# Processed and saved: ./emotional-data/F93.json
# Processed and saved: ./emotional-data/F94.json
# Processed and saved: ./emotional-data/F95.json
# Processed and saved: ./emotional-data/F96.json
# Processed and saved: ./emotional-data/F97.json
